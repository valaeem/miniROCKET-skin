# %%
#import numpy as np
from sklearn.linear_model import RidgeClassifierCV
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

#from sktime.datasets import load_arrow_head  # univariate dataset
#from sktime.datasets import load_basic_motions  # multivariate dataset
#from sktime.datasets import (
#    load_japanese_vowels,  # multivariate dataset with unequal length
#)
from sktime.transformations.panel.rocket import (
    MiniRocket,
    MiniRocketMultivariate,
    MiniRocketMultivariateVariable,
)


from sktime.transformations.panel.rocket import MiniRocketMultivariate

import os
import cv2
import csv
import time

import numpy as np

folderRoot = "C:\\Users\\Mel\\Desktop\\University\\3rd Year\\3H06\\(mini)ROCKET\\Final"


from minirocket import fit, transform
from sklearn.linear_model import RidgeClassifierCV

#import cv2
#import csv
#import time

#from sklearn.model_selection import train_test_split

#folderRoot = "C:\\Users\\Mel\\Desktop\\University\\3rd Year\\3H06\\(mini)ROCKET\\Skin Cancer"

# %%
X_train = []
y_train = []
X_test = []
y_test = []

#sampleSize = 30

path = folderRoot + "\\train"
print(path)
for img in os.listdir(path):
    pic = cv2.imread(os.path.join(path,img))
    pic = cv2.cvtColor(pic,cv2.COLOR_BGR2RGB)
    #pic = cv2.resize(pic,(80,80))
    #pic = cv2.resize(pic,(450,450))
    #pic = cv2.resize(pic,(300,300))
    X_train.append([pic])
    csv_file = csv.reader(open(folderRoot + "\\HAM10000_metadata.csv", "r"), delimiter=",")
    for row in csv_file:
        if (row[1]+".jpg" == img):
            y_train.append(row[2])

        #plt.imshow(np.array(X[0]).reshape(450,450,3))
        
   # if(len(X_train) == sampleSize):
    #    break

length = len(X_train)
print(length)

path = folderRoot + "\\test\\ISIC2018_Task3_Validation_Input"
print(path)
for img in os.listdir(path):
    pic = cv2.imread(os.path.join(path,img))
    pic = cv2.cvtColor(pic,cv2.COLOR_BGR2RGB)
    #pic = cv2.resize(pic,(80,80))
    #pic = cv2.resize(pic,(450,450))
    #pic = cv2.resize(pic,(300,300))
    X_test.append([pic])
    csv_file = csv.reader(open(folderRoot + "\\test\\ISIC2018_Task3_Validation_GroundTruth\\ISIC2018_Task3_Validation_GroundTruth.csv", "r"), delimiter=",")
    for row in csv_file:
        if (row[0] + ".jpg" == img):
            if(row[1] == "1.0"):
                y_test.append("mel")
            if(row[2] == "1.0"):
                y_test.append("nv")
            if(row[3] == "1.0"):
                y_test.append("bcc")    
            if(row[4] == "1.0"):
                y_test.append("akiec")
            if(row[5] == "1.0"):
                y_test.append("bkl")
            if(row[6] == "1.0"):
                y_test.append("df")
            if(row[7] == "1.0"):
                y_test.append("vasc")

        #plt.imshow(np.array(X[0]).reshape(450,450,3))
        
    #if(len(X_test) == sampleSize):
     #   break

length = len(X_test)

print(length)

path = folderRoot + "\\test\\ISIC2018_Task3_Test_Input"
print(path)
for img in os.listdir(path):
    pic = cv2.imread(os.path.join(path,img))
    pic = cv2.cvtColor(pic,cv2.COLOR_BGR2RGB)
    #pic = cv2.resize(pic,(80,80))
    #pic = cv2.resize(pic,(450,450))
    #pic = cv2.resize(pic,(300,300))
    X_test.append([pic])
    csv_file = csv.reader(open(folderRoot + "\\test\\ISIC2018_Task3_Test_GroundTruth\\ISIC2018_Task3_Test_GroundTruth.csv", "r"), delimiter=",")
    for row in csv_file:
        if (row[0] + ".jpg" == img):
            if(row[1] == "1.0"):
                y_test.append("mel")
            if(row[2] == "1.0"):
                y_test.append("nv")
            if(row[3] == "1.0"):
                y_test.append("bcc")    
            if(row[4] == "1.0"):
                y_test.append("akiec")
            if(row[5] == "1.0"):
                y_test.append("bkl")
            if(row[6] == "1.0"):
                y_test.append("df")
            if(row[7] == "1.0"):
                y_test.append("vasc")

        #plt.imshow(np.array(X[0]).reshape(450,450,3))
        
    #if(len(X_test) == sampleSize*2):
     #   break

length = len(X_test)

print(length)

X_train = np.array(X_train)
y_train = np.array(y_train)
X_test = np.array(X_test)
y_test = np.array(y_test)

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, train_size=0.8, random_state=42)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
#y_train = y_train.astype('float32')
#y_test = y_test.astype('float32')

print('X_train.shape:', X_train.shape)
print('X_test.shape:', X_test.shape)
print('Y_train.shape:', y_train.shape)
print('Y_test.shape:', y_test.shape)

print('X_train.shape:', X_train.dtype)
# Out:
# C:\Users\Mel\Desktop\University\3rd Year\3H06\(mini)ROCKET\Final\train
# 10015
# C:\Users\Mel\Desktop\University\3rd Year\3H06\(mini)ROCKET\Final\test\ISIC2018_Task3_Validation_Input
# 193
# C:\Users\Mel\Desktop\University\3rd Year\3H06\(mini)ROCKET\Final\test\ISIC2018_Task3_Test_Input
# 1705
# X_train.shape: (10015, 1, 450, 600, 3)
# X_test.shape: (1705, 1, 450, 600, 3)
# Y_train.shape: (10015,)
# Y_test.shape: (1705,)
# X_train.shape: float32

# %%
X_train = X_train.reshape((X_train.shape[0], -1))
X_test = X_test.reshape((X_test.shape[0], -1))
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (10015, 810000)
# (1705, 810000)
# (10015,)
# (1705,)

# %%
start_fit = time.time()

parameters = fit(X_train)

X_training_transform = transform(X_train, parameters)

classifier = RidgeClassifierCV(alphas = np.logspace(-3, 3, 10))
classifier.fit(X_training_transform, y_train)

end_fit = time.time()

X_test_transform = transform(X_test, parameters)

predictions = classifier.predict(X_test_transform)

score = classifier.score(X_test_transform, y_test)

end_test = time.time()

print('Fit time:', end_fit - start_fit, 'seconds')
print('Test time:', end_test - end_fit, 'seconds')
print('Accuracy:', score)
# Out:
# Fit time: 31005.010091543198 seconds
# Test time: 5014.270501613617 seconds
# Accuracy: 0.7296187683284457
